# %%
import numpy as np

# %%
x = np.arange(0,5, 0.1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y = 3*np.cos(2.5*x)-np.sin(2.5*x)

# %%
plt.plot(x,y)

# %%
y= 2.2*np.exp(-0.3*x)
